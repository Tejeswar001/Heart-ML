# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../Data/cleaned_data.csv')
df.head()
# Out:
#   Sex   Age  Weight (kg)  Height (m)   BMI  Abdominal Circumference (cm)  \
# 0   F  32.0      69.1000        1.71  23.6                          86.2
# 1   F  55.0     118.7000        1.69  41.6                          82.5
# 2   M  46.0      86.6145        1.83  25.9                         106.7
# 3   M  44.0     108.3000        1.80  33.4                          96.6
# 4   F  32.0      99.5000        1.86  28.8                         102.7
#
#    Total Cholesterol (mg/dL)  HDL (mg/dL)  Fasting Blood Sugar (mg/dL)  \
# 0                      248.0         78.0                        111.0
# 1                      162.0         50.0                        135.0
# 2                      103.0         73.0                        114.0
# 3                      134.0         46.0                         91.0
# 4                      146.0         64.0                        141.0
#
#   Smoking Status  ... Physical Activity Level Family History of CVD  \
# 0              N  ...                     Low                     N
# 1              Y  ...                    High                     Y
# 2              N  ...                    High                     Y
# 3              N  ...                    High                     Y
# 4              Y  ...                    High                     N
#
#   CVD Risk Level Height (cm)  Waist-to-Height Ratio  Systolic BP  \
# 0   INTERMEDIARY     171.000                  0.504        125.0
# 1           HIGH     169.000                  0.488        139.0
# 2   INTERMEDIARY     183.000                  0.583        104.0
# 3   INTERMEDIARY     175.694                  0.537        140.0
# 4   INTERMEDIARY     186.000                  0.552        144.0
#
#    Diastolic BP  Blood Pressure Category Estimated LDL (mg/dL)  CVD Risk Score
# 0          79.0                 Elevated                 140.0           17.93
# 1          70.0     Hypertension Stage 1                  82.0           20.51
# 2          77.0                   Normal                   0.0           12.64
# 3          83.0     Hypertension Stage 1                  58.0           16.36
# 4          83.0     Hypertension Stage 1                  52.0           17.88
#
# [5 rows x 21 columns]

# %% [markdown]
# # Clinical Sanity Checks & Edge Cases to Handle

# %% [markdown]
# ## Blood Pressure Consistency

# %% [markdown]
# 1. Systolic BP > Diastolic BP
#
# > Always true medically

# %%
df[df['Systolic BP'] > df['Diastolic BP']].shape
# Out:
# (1463, 21)

# %%
df[df['Systolic BP'] < df['Diastolic BP']].shape
# Out:
# (60, 21)

# %% [markdown]
# Let's not consider records where Systolic BP is less than Diastolic BP

# %%
df = df[df['Systolic BP'] > df['Diastolic BP']]

# %% [markdown]
# 2. Realistic BP Ranges
#
# | Measurement   |   Min   |   Max   |
# |---------------|---------|---------|
# | Systolic      |    80   |  250    |
# | Diastolic     |    40   |  150    |

# %%
df[
    (df['Systolic BP'].between(80, 250)) &
    (df['Diastolic BP'].between(40, 150))
]
# Out:
#      Sex   Age  Weight (kg)  Height (m)   BMI  Abdominal Circumference (cm)  \
# 0      F  32.0      69.1000       1.710  23.6                     86.200000
# 1      F  55.0     118.7000       1.690  41.6                     82.500000
# 2      M  46.0      86.6145       1.830  25.9                    106.700000
# 3      M  44.0     108.3000       1.800  33.4                     96.600000
# 4      F  32.0      99.5000       1.860  28.8                    102.700000
# ...   ..   ...          ...         ...   ...                           ...
# 1523   M  63.0      91.6250       1.702  31.6                    105.592094
# 1524   F  40.0      72.0700       1.889  20.2                     95.326000
# 1526   M  39.0      98.6260       1.521  42.6                     77.193000
# 1527   M  71.0     116.1630       1.841  34.3                    114.197000
# 1528   F  78.0     111.6270       1.867  32.0                     97.692000
#
#       Total Cholesterol (mg/dL)  HDL (mg/dL)  Fasting Blood Sugar (mg/dL)  \
# 0                         248.0         78.0                        111.0
# 1                         162.0         50.0                        135.0
# 2                         103.0         73.0                        114.0
# 3                         134.0         46.0                         91.0
# 4                         146.0         64.0                        141.0
# ...                         ...          ...                          ...
# 1523                      189.0         76.0                        153.0
# 1524                      157.0         60.0                         93.0
# 1526                      237.0         82.0                        147.0
# 1527                      193.0         84.0                        123.0
# 1528                      218.0         68.0                        166.0
#
#      Smoking Status  ... Physical Activity Level Family History of CVD  \
# 0                 N  ...                     Low                     N
# 1                 Y  ...                    High                     Y
# 2                 N  ...                    High                     Y
# 3                 N  ...                    High                     Y
# 4                 Y  ...                    High                     N
# ...             ...  ...                     ...                   ...
# 1523              N  ...                Moderate                     N
# 1524              N  ...                Moderate                     Y
# 1526              N  ...                    High                     N
# 1527              N  ...                    High                     Y
# 1528              N  ...                    High                     N
#
#      CVD Risk Level Height (cm)  Waist-to-Height Ratio  Systolic BP  \
# 0      INTERMEDIARY     171.000                  0.504        125.0
# 1              HIGH     169.000                  0.488        139.0
# 2      INTERMEDIARY     183.000                  0.583        104.0
# 3      INTERMEDIARY     175.694                  0.537        140.0
# 4      INTERMEDIARY     186.000                  0.552        144.0
# ...             ...         ...                    ...          ...
# 1523   INTERMEDIARY     175.694                  0.601        162.0
# 1524            LOW     188.894                  0.505        119.0
# 1526   INTERMEDIARY     152.119                  0.507        150.0
# 1527   INTERMEDIARY     184.059                  0.620        112.0
# 1528           HIGH     186.735                  0.523        134.0
#
#       Diastolic BP  Blood Pressure Category Estimated LDL (mg/dL)  \
# 0             79.0                 Elevated                 140.0
# 1             70.0     Hypertension Stage 1                  82.0
# 2             77.0                   Normal                   0.0
# 3             83.0     Hypertension Stage 1                  58.0
# 4             83.0     Hypertension Stage 1                  52.0
# ...            ...                      ...                   ...
# 1523          60.0     Hypertension Stage 2                  83.0
# 1524          66.0                   Normal                  67.0
# 1526          90.0     Hypertension Stage 2                 125.0
# 1527          63.0                   Normal                  79.0
# 1528          67.0     Hypertension Stage 1                 120.0
#
#       CVD Risk Score
# 0             17.930
# 1             20.510
# 2             12.640
# 3             16.360
# 4             17.880
# ...              ...
# 1523          20.936
# 1524          14.300
# 1526          18.251
# 1527          15.316
# 1528          15.463
#
# [1463 rows x 21 columns]

# %% [markdown]
# 3. BP Category Must Match Readings
#
# Mapping:
#
# - Normal: <120 / <80
#
# - Elevated: 120–129 / <80
#
# - Hypertension Stage 1: 130–139 / 80–89
#
# - Hypertension Stage 2: ≥140 / ≥90

# %%
def validate_bp_category(row):
    sbp = row['Systolic BP']
    dbp = row['Diastolic BP']

    if sbp < 120 and dbp < 80:
        return 'Normal'
    elif 120 <= sbp < 130 and dbp < 80:
        return 'Elevated'
    elif (130 <= sbp < 140) or (80 <= dbp < 90):
        return 'Hypertension Stage 1'
    elif (140 <= sbp) or (90 <= dbp):
        return 'Hypertension Stage 2'
    else:
        return 'Hypertensive Crisis'

# %%
df.apply(validate_bp_category, axis=1).value_counts()
# Out:
# Hypertension Stage 2    566
# Hypertension Stage 1    497
# Normal                  300
# Elevated                100
# Name: count, dtype: int64

# %% [markdown]
# > No mismatch found

# %% [markdown]
# ## Height, Weight & BMI Consistency

# %% [markdown]
# 4. Height(cm) <-> Height(m)

# %%
df[df['Height (cm)'] == df['Height (m)']*100].shape
# Out:
# (895, 21)

# %%
df[
    abs(df['Height (cm)'] - df['Height (m)']*100) < 26
].shape
# Out:
# (1463, 21)

# %% [markdown]
# 5. BMI Formula Must Hold
#
# BMI = Weight/height<sup>2

# %%
df['BMI_calculated'] = df['Weight (kg)'] / (df['Height (m)']**2)
df[df['BMI'] == df['BMI_calculated'].round(1)].shape
# Out:
# (1463, 22)

# %% [markdown]
# 6. Vaild Ranges
#
# | Feature       |   Range |
# |---------------|---------|
# | Height (m)      |1.2-2.2   |
# | Weight (kg)     | 30-200  |
# | BMI           |   10-60 |

# %%
df[
    df['Height (m)'].between(1.2, 2.2) &
    df['Weight (kg)'].between(30, 200) &
    df['BMI'].between(10, 60)
].shape
# Out:
# (1463, 22)

# %% [markdown]
# > Nothing abnormal

# %% [markdown]
# ## Cholesterol & Lipid Profile Rules

# %% [markdown]
# 7. HDL < Total Cholesterol

# %%
df[df['HDL (mg/dL)'] < df['Total Cholesterol (mg/dL)']].shape == df.shape
# Out:
# True

# %% [markdown]
# 8. LDL < Total Cholesterol

# %%
df[df['Estimated LDL (mg/dL)'] < df['Total Cholesterol (mg/dL)']].shape
# Out:
# (1454, 22)

# %%
df[df['Estimated LDL (mg/dL)'] >= df['Total Cholesterol (mg/dL)']][['Estimated LDL (mg/dL)', 'HDL (mg/dL)','Total Cholesterol (mg/dL)']]
# Out:
#       Estimated LDL (mg/dL)  HDL (mg/dL)  Total Cholesterol (mg/dL)
# 85                    109.0         79.0                      102.0
# 232                   109.0         42.0                      109.0
# 389                   226.0         37.0                      197.0
# 468                   109.0         67.0                      101.0
# 487                   206.0         55.0                      197.0
# 826                   202.0         37.0                      197.0
# 996                   210.0         47.0                      197.0
# 1246                  109.0         37.0                      108.0
# 1511                  209.0         33.0                      197.0

# %%
df = df[df['Estimated LDL (mg/dL)'] < df['Total Cholesterol (mg/dL)']]

# %% [markdown]
# 9. Realistic Liqid Ranges
#
# | Feature           | Range   |
# | ----------------- | ------- |
# | Total Cholesterol | 100–400 |
# | HDL               | 20–100  |
# | LDL               | 50–250  |

# %%
df[
    df['Total Cholesterol (mg/dL)'].between(100, 400) &
    df['HDL (mg/dL)'].between(20, 100) &
    df['Estimated LDL (mg/dL)'].between(50, 250)
].shape
# Out:
# (1198, 22)

# %%
df[~df['Estimated LDL (mg/dL)'].between(50, 250)]['Estimated LDL (mg/dL)']
# Out:
# 2        0.0
# 15      44.0
# 22      43.0
# 25      47.0
# 39       7.0
#         ...
# 1467    43.0
# 1468    26.0
# 1500    45.0
# 1506    -3.0
# 1514    36.0
# Name: Estimated LDL (mg/dL), Length: 256, dtype: float64

# %%
# Keep clinically valid LDL
df = df[df['Estimated LDL (mg/dL)'] >= 30]

# %% [markdown]
# ## Waist to Height Ratio Logic

# %% [markdown]
# 11. Ratio Formula

# %%
(df['Abdominal Circumference (cm)'] / df['Height (cm)']).between(0.3, 0.7).shape[0] == df.shape[0]
# Out:
# True

# %% [markdown]
# ## Age-Based Sanity Checks

# %% [markdown]
# 12. Age vs Risk
#
# If:
#
# - Age < 30 → High risk should be rare
#
# - Age > 60 → High risk likely

# %%
df.groupby('CVD Risk Level')['Age'].mean()
# Out:
# CVD Risk Level
# HIGH            47.500750
# INTERMEDIARY    45.238095
# LOW             48.354497
# Name: Age, dtype: float64

# %%
df['Age'].describe()
# Out:
# count    1360.000000
# mean       46.780882
# std        11.907193
# min        25.000000
# 25%        37.000000
# 50%        46.000000
# 75%        55.000000
# max        79.000000
# Name: Age, dtype: float64

# %% [markdown]
# ## Risk Score & Risk Level Alignment

# %% [markdown]
# 13. Score <-> Level

# %% [markdown]
# | Risk Level | Score Range |
# | ---------- | ----------- |
# | Low        | 0–10        |
# | Medium     | 10–20       |
# | High       | >20         |

# %%
df.groupby('CVD Risk Level')['CVD Risk Score'].aggregate(['mean','max','min','median'])
# Out:
#                      mean     max    min     median
# CVD Risk Level
# HIGH            17.726161  24.170  11.25  17.630000
# INTERMEDIARY    16.270586  23.510  10.53  16.133444
# LOW             17.147066  23.797  10.86  17.006419

# %% [markdown]
# ## Smoking & Age Rule (Soft Check)

# %% [markdown]
# Smoking status for age < 12 -> invaild

# %%
df[~((df['Age'] < 12) & (df['Smoking Status'] == 1))].shape[0] == df.shape[0]
# Out:
# True

# %%
df.to_csv('../Data/cvd_validated_dataset.csv', index=False)
